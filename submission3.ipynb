# %%
from IPython import display

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, Model, losses
from sklearn.metrics import accuracy_score

# %%
df_train = pd.read_csv('data/train.csv')  
lable_train = np.array(df_train.iloc()[:,0]).reshape((42000))
data_train = np.array(df_train.iloc()[:,1:]).reshape((42000,28,28,1))

df_test = pd.read_csv('data/test.csv')  
data_test = np.array(df_test.iloc()[:,:])

# %%
lable_train.shape
temp = np.repeat(np.zeros(10), 42000, axis=0).astype(int).reshape(42000,10)
temp[np.arange(42000),lable_train] = 1 
lable_train =  temp
lable_train.shape
# Out:
# (42000, 10)

# %%
data_train.shape
# Out:
# (42000, 28, 28, 1)

# %%
data_test.shape
# Out:
# (28000, 784)

# %%
data_test = data_test.reshape((28000,28,28,1))

# %%
class CNN(Model):
    def __init__(self):
        super(CNN, self).__init__()
        self.CNN_ = tf.keras.Sequential([
            layers.Input(shape=(28,28,1)),
            
            layers.Conv2D(32, (5,5), padding="same", activation='relu'),
            layers.Conv2D(32, (5,5), padding="same", activation='relu'),
            layers.Conv2D(32, (5,5), padding="same", activation='relu'),
                        
            layers.Flatten(),
            layers.Dense(100),
            layers.Dense(10, activation='softmax')
        ])
        

    def call(self, x):
        output = self.CNN_(x)
        return output

# %%
modelCNN = CNN()
modelCNN.compile(optimizer='adam', loss="categorical_crossentropy")
modelCNN.fit(data_train, lable_train,epochs=5)
# Out:
# Epoch 1/5
# 1313/1313 [==============================] - 138s 105ms/step - loss: 2.4384
# Epoch 2/5
# 1313/1313 [==============================] - 198s 151ms/step - loss: 0.0905
# Epoch 3/5
# 1313/1313 [==============================] - 215s 163ms/step - loss: 0.0721
# Epoch 4/5
# 1313/1313 [==============================] - 140s 106ms/step - loss: 0.0675
# Epoch 5/5
# 1313/1313 [==============================] - 122s 93ms/step - loss: 0.0545

# %%
result_train = modelCNN.CNN_(data_train)
result_test = modelCNN.CNN_(data_test)

# %%
np.argmax(result_train, axis=1)
# Out:
# array([1, 0, 1, ..., 7, 6, 9])

# %%
np.argmax(result_test, axis=1)
# Out:
# array([2, 0, 9, ..., 3, 9, 2])

# %%
submission = pd.read_csv('data/sample_submission.csv')

# %%
submission["Label"] = np.argmax(result_test, axis=1)

# %%
submission.to_csv("submission/submission3.csv", index=False)

# %% [markdown]
# # Score : 0.98396
